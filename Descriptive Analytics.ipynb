# %% [markdown]
# - Descriptive Analytics
#     - Working with DataFrames in Python
#     - Handling Missing Values
#     - Exploration of Data using Visualization

# %% [markdown]
# <h1><font color='red'>Descriptive Analytics</font></h1></br>
#
# **Descriptive Analytics** is the examination of data or content, usually manually performed,
# to answer the question “What happened?” (or What is happening?), characterized by
# traditional business intelligence (BI) and visualizations such as pie charts, bar
# charts, line graphs, tables, or generated narratives.
#
# **Example :**
# Summarising past events such as sales and operations data or marketing campaigns. Social media usage and engagement data such as Instagram or Facebook likes. Reporting general trends. Collating survey results

# %% [markdown]
# **Working with DataFrames in Python**
#
# https://realpython.com/pandas-dataframe/#working-with-time-series

# %% [markdown]
# ### Introducing the Pandas DataFrame
#
# Pandas DataFrames are data structures that contain:
# - Data organized in two dimensions, rows and columns
# - Labels that correspond to the rows and columns

# %%
import pandas as pd
data = {'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
        'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai','Manchester', 'Cairo', 'Osaka'],
        'age': [41, 28, 33, 34, 38, 31, 37],
        'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]}
row_labels = [101, 102, 103, 104, 105, 106, 107]
df = pd.DataFrame(data=data, index=row_labels)

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html
titanic_df = pd.read_csv('titanic.csv')

# %%
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# gives the number of rows and columns in the dataframe
titanic_df.shape
# Out:
# (891, 12)

# %%
# I’m interested in the passengers older than 35 years.
titanic_df_age_older_35 = titanic_df[titanic_df['Age']>35]

# %%
# I’m interested in the Titanic passengers from cabin class 2 and 3.
titanic_pclass = titanic_df[titanic_df['Pclass'].isin([2,3])]

# %% [markdown]
# ### or we can use below method for that we need to use the <font color="red">or</font> operator <font color="red">|</font> and the <font color="red">and</font> operator <font color="red">&</font>.

# %%
class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]

# %%
# I want to work with passenger data for which the age is known.
known_age = titanic_df[titanic_df['Age'].notna()]

# %%
# I’m interested in the names of the passengers older than 35 years.
t = titanic_df.loc[titanic_df['Age']>35,'Name']
# or 
t = titanic_df[titanic_df['Age']>35]['Name']

# %%
# I’m interested in rows 10 till 25 and columns 3 to 5.
t = titanic_df.iloc[9:25, 2:5]

# %% [markdown]
# ### <font color='#00008B'>How to create plots in pandas?</font>

# %%
import matplotlib.pyplot as plt

# %%
titanic_df.plot()
# With a DataFrame, pandas creates by default one line plot for each of the columns with numeric data.

# %%
titanic_df.plot.scatter(x='Age',y='Pclass',alpha=0.3)

# %% [markdown]
# ### <font color='#00008B'>How to create new columns derived from existing columns?</font>

# %%
sample_exp_df = titanic_df.copy().head()

# %%
sample_exp_df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  encoded_id
# 0      0  A/5 21171  7.25   NaN        S           2

# %%
sample_exp_df['encoded_id'] = sample_exp_df['PassengerId'] * 2

# %%
sample_exp_df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  encoded_id
# 0      0  A/5 21171  7.25   NaN        S           2

# %% [markdown]
# ### <font color='#00008B'>How to calculate summary statistcs?</font>

# %%
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html

# %%
# What is the average age of the Titanic passengers?
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# What is the median age and ticket fare price of the Titanic passengers?
titanic_df[['Age','Fare']].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64
